# %%
from reportlab.pdfgen import canvas 
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfgen import canvas 
import speech_recognition as sr
import pyttsx3
import string

fileName="Cv2.pdf"
documentTitle = 'Document title!'
pdf = canvas.Canvas(fileName)
pdf.setTitle(documentTitle)

pdfmetrics.registerFont(
    TTFont('abc', 'SakBunderan.ttf')
)
pdf.setFont('abc', 12)
engine=pyttsx3.init()
r=sr.Recognizer()
engine.setProperty('rate',150)
engine.say("what is your name?")
engine.runAndWait()
try:
    with sr.Microphone() as source:
        audio = r.listen(source)
        r.adjust_for_ambient_noise(source,duration=0.5)

    msg = r.recognize_google(audio)
except:
    engine.say("can't understand the name")
    engine.runAndWait()
print(msg)
pdf.drawString(250,800,msg)
engine.say("what is your mail id?")
engine.runAndWait()
try:
    with sr.Microphone() as source:
        audio = r.listen(source)
        r.adjust_for_ambient_noise(source,duration=0.5)

    msg = r.recognize_google(audio)
except:
    engine.say("can't understand the name")
    engine.runAndWait()
print(msg)
pdf.drawString(230,783,msg)
engine.say("what is your phone no?")
engine.runAndWait()
try:
    with sr.Microphone() as source:
        audio = r.listen(source)
        r.adjust_for_ambient_noise(source,duration=0.5)

    msg = r.recognize_google(audio)
    msg.strip()
except:
    engine.say("can't understand the name")
    engine.runAndWait()
print(msg)
pdf.drawString(245,766,msg)
pdf.line(0,752,600,752)
textLines =['To work in challenging environment and adapt myself in different fields with impressive',
          'performance and making things more amd more better']
pdf.setFont('abc',15)
pdf.drawString(27,736,"Objective:")
pdf.setFont('abc',12)
text = pdf.beginText(50, 720)
for line in textLines:
    text.textLine(line)

pdf.drawText(text)
engine.say("tell about your two skills?")
engine.runAndWait()
pdf.setFont('abc',15)
pdf.drawString(27,680,"Skills:")
pdf.setFont('abc',12)
for i in range(640,680,20):
    try:
        with sr.Microphone() as source:
            audio = r.listen(source)
            r.adjust_for_ambient_noise(source,duration=0.5)

        msg = r.recognize_google(audio)
        msg.strip()
    except:
        engine.say("can't understand the name")
        engine.runAndWait()
    pdf.drawString(50,i, u'\u2022 '+ msg)
engine.say("tell about your three programming languages that you know?")
engine.runAndWait()
pdf.setFont('abc',15)
pdf.drawString(27,620,"Languages:")
pdf.setFont('abc',12)
for i in range(560,620,20):
    try:
        with sr.Microphone() as source:
            audio = r.listen(source)
            r.adjust_for_ambient_noise(source,duration=0.5)

        msg = r.recognize_google(audio)
        msg.strip()
    except:
        engine.say("can't understand the name")
        engine.runAndWait()
    pdf.drawString(50,i, u'\u2022 '+ msg)
engine.say("tell about your three soft skills?")
engine.runAndWait()
pdf.setFont('abc',15)
pdf.drawString(27,540,"Soft Skills:")
pdf.setFont('abc',12)
for i in range(480,540,20):
    try:
        with sr.Microphone() as source:
            audio = r.listen(source)
            r.adjust_for_ambient_noise(source,duration=0.5)

        msg = r.recognize_google(audio)
        msg.strip()
    except:
        engine.say("can't understand the name")
        engine.runAndWait()
    pdf.drawString(50,i, u'\u2022 '+ msg)
engine.say("tell about your three certifications?")
engine.runAndWait()
pdf.setFont('abc',15)
pdf.drawString(27,460,"Certification :")
pdf.setFont('abc',12)
for i in range(400,460,20):
    try:
        with sr.Microphone() as source:
            audio = r.listen(source)
            r.adjust_for_ambient_noise(source,duration=0.5)

        msg = r.recognize_google(audio)
        msg.strip()
    except:
        engine.say("can't understand the name")
        engine.runAndWait()
    pdf.drawString(50,i, u'\u2022 '+ msg)
engine.say("tell about your three achievements ?")
engine.runAndWait()
pdf.setFont('abc',15)
pdf.drawString(27,380,"Achievements :")
pdf.setFont('abc',12)
for i in range(320,380,20):
    try:
        with sr.Microphone() as source:
            audio = r.listen(source)
            r.adjust_for_ambient_noise(source,duration=0.5)

        msg = r.recognize_google(audio)
        msg.strip()
    except:
        engine.say("can't understand the name")
        engine.runAndWait()
    pdf.drawString(50,i, u'\u2022 '+ msg)
engine.say("tell about your two experiences?")
engine.runAndWait()
pdf.setFont('abc',15)
pdf.drawString(27,300,"Experience :")
pdf.setFont('abc',12)
for i in range(260,300,20):
    try:
        with sr.Microphone() as source:
            audio = r.listen(source)
            r.adjust_for_ambient_noise(source,duration=0.5)

        msg = r.recognize_google(audio)
        msg.strip()
    except:
        engine.say("can't understand the name")
        engine.runAndWait()
    pdf.drawString(50,i, u'\u2022 '+ msg)
engine.say("tell about your two hobbies?")
engine.runAndWait()
pdf.setFont('abc',15)
pdf.drawString(27,240,"Hobbies :")
pdf.setFont('abc',12)
for i in range(200,240,20):
    try:
        with sr.Microphone() as source:
            audio = r.listen(source)
            r.adjust_for_ambient_noise(source,duration=0.5)

        msg = r.recognize_google(audio)
        msg.strip()
    except:
        engine.say("can't understand the name")
        engine.runAndWait()
    pdf.drawString(50,i, u'\u2022 '+ msg)
pdf.drawString(27,180,"Academics")
pdf.line(10,160,550,160)
pdf.line(10,30,550,30)
pdf.line(10,160,10,30)
pdf.line(550,160,550,30)

pdf.line(120,160,120,30)
pdf.line(300,160,300,30)
pdf.line(430,160,430,30)

pdf.line(10,120,550,120)
pdf.line(10,90,550,90)
pdf.line(10,60,550,60)
pdf.drawString(25,140,"Qualification")
pdf.drawString(135,140,"University")
pdf.drawString(315,140,"Year of passing")
pdf.drawString(450,140,"Percentage")
pdf.drawString(25,100,"B.Tech")
pdf.drawString(25,70,"XII")
pdf.drawString(25,40,"X")
engine.say("Board of your btech?")
engine.runAndWait()
try:
    with sr.Microphone() as source:
        audio = r.listen(source)
        r.adjust_for_ambient_noise(source,duration=0.5)

    msg = r.recognize_google(audio)
except:
    engine.say("can't understand the name")
    engine.runAndWait()
print(msg)
pdf.drawString(135,100,msg)
engine.say("year of passing")
engine.runAndWait()
try:
    with sr.Microphone() as source:
        audio = r.listen(source)
        r.adjust_for_ambient_noise(source,duration=0.5)

    msg = r.recognize_google(audio)
except:
    engine.say("can't understand the name")
    engine.runAndWait()
print(msg)
pdf.drawString(315,100,msg)
engine.say("cgpa in btech?")
engine.runAndWait()
try:
    with sr.Microphone() as source:
        audio = r.listen(source)
        r.adjust_for_ambient_noise(source,duration=0.5)

    msg = r.recognize_google(audio)
except:
    engine.say("can't understand the name")
    engine.runAndWait()
print(msg)
pdf.drawString(450,100,msg)
engine.say("board of your class twelve?")
engine.runAndWait()
try:
    with sr.Microphone() as source:
        audio = r.listen(source)
        r.adjust_for_ambient_noise(source,duration=0.5)

    msg = r.recognize_google(audio)
except:
    engine.say("can't understand the name")
    engine.runAndWait()
print(msg)
pdf.drawString(135,70,msg)
engine.say("Year of passing")
engine.runAndWait()
try:
    with sr.Microphone() as source:
        audio = r.listen(source)
        r.adjust_for_ambient_noise(source,duration=0.5)

    msg = r.recognize_google(audio)
except:
    engine.say("can't understand the name")
    engine.runAndWait()
print(msg)
pdf.drawString(315,70,msg)
engine.say("percentage in twelve")
engine.runAndWait()
try:
    with sr.Microphone() as source:
        audio = r.listen(source)
        r.adjust_for_ambient_noise(source,duration=0.5)

    msg = r.recognize_google(audio)
except:
    engine.say("can't understand the name")
    engine.runAndWait()
print(msg)
pdf.drawString(450,70,msg)
engine.say("Board name in class ten?")
engine.runAndWait()
try:
    with sr.Microphone() as source:
        audio = r.listen(source)
        r.adjust_for_ambient_noise(source,duration=0.5)

    msg = r.recognize_google(audio)
except:
    engine.say("can't understand the name")
    engine.runAndWait()
print(msg)
pdf.drawString(135,40,msg)
engine.say("year of passing?")
engine.runAndWait()
try:
    with sr.Microphone() as source:
        audio = r.listen(source)
        r.adjust_for_ambient_noise(source,duration=0.5)

    msg = r.recognize_google(audio)
except:
    engine.say("can't understand the name")
    engine.runAndWait()
print(msg)
pdf.drawString(315,40,msg)
engine.say("Percentage?")
engine.runAndWait()
try:
    with sr.Microphone() as source:
        audio = r.listen(source)
        r.adjust_for_ambient_noise(source,duration=0.5)

    msg = r.recognize_google(audio)
except:
    engine.say("can't understand the name")
    engine.runAndWait()
print(msg)
pdf.drawString(450,40,msg)
engine.say("YOur c v is ready")
engine.runAndWait()


pdf.save()
# Out:
# Arnab Das
# Arnab @ gmail.com
# 7044 076 948
# m a k a u t
# 2022
# 7.00
# w b c h s e
# 2018
# 8 1.02
# WWE
# 2016
# 89.1 6

# %%
from reportlab.pdfgen import canvas

c = canvas.Canvas("test.pdf")
c.drawString(100, 100, u'\u2022 First sentence')
c.save()

# %%
from reportlab.pdfgen import canvas 
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfgen import canvas 
import speech_recognition as sr
import pyttsx3
import string

pdf = canvas.Canvas("test.pdf")
pdfmetrics.registerFont(
    TTFont('abc', 'SakBunderan.ttf')
)
pdf.setFont('abc', 12)
engine=pyttsx3.init()
r=sr.Recognizer()
engine.setProperty('rate',150)
pdf.drawString(27,180,"Academics")
pdf.line(10,160,550,160)
pdf.line(10,30,550,30)
pdf.line(10,160,10,30)
pdf.line(550,160,550,30)

pdf.line(120,160,120,30)
pdf.line(300,160,300,30)
pdf.line(430,160,430,30)

pdf.line(10,120,550,120)
pdf.line(10,90,550,90)
pdf.line(10,60,550,60)
pdf.drawString(25,140,"Qualification")
pdf.drawString(135,140,"University")
pdf.drawString(315,140,"Year of passing")
pdf.drawString(450,140,"Percentage")
pdf.drawString(25,100,"B.Tech")
pdf.drawString(25,70,"XII")
pdf.drawString(25,40,"X")
pdf.showPage()
pdf.drawString(200,800,"hhiii")


pdf.save()
